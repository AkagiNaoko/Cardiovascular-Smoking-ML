# %%
import pandas as pd
from pathlib import Path

# %%
# Read in the CSV file as a Pandas DataFrame
cardio_df = pd.read_csv(
    Path("Cardio_Behavioral_Risk_Factor_Surveillance_System__BRFSS__-__National_Cardiovascular_Disease_Surveillance_Data.csv")
)

# Review the DataFrame
cardio_df.head()
# Out:
#                                         RowId  YearStart LocationAbbr  \
# 0  BRFSS~2011~01~BR001~OVR01~Age-Standardized       2011           AL
# 1             BRFSS~2011~01~BR001~OVR01~Crude       2011           AL
# 2             BRFSS~2011~01~BR001~GEN01~Crude       2011           AL
# 3  BRFSS~2011~01~BR001~GEN01~Age-Standardized       2011           AL
# 4  BRFSS~2011~01~BR001~GEN02~Age-Standardized       2011           AL
#
#   LocationDesc DataSource PriorityArea1  PriorityArea2 PriorityArea3  \
# 0      Alabama      BRFSS          None            NaN          None
# 1      Alabama      BRFSS          None            NaN          None
# 2      Alabama      BRFSS          None            NaN          None
# 3      Alabama      BRFSS          None            NaN          None
# 4      Alabama      BRFSS          None            NaN          None
#
#    PriorityArea4                    Class  ... Break_Out_Category Break_Out  \
# ...

# %%
# remove crude prevelance
cardio_df = cardio_df.loc[(cardio_df["Data_Value_Type"] == "Age-Standardized"),:]
cardio_df
# Out:
#                                              RowId  YearStart LocationAbbr  \
# 0       BRFSS~2011~01~BR001~OVR01~Age-Standardized       2011           AL
# 3       BRFSS~2011~01~BR001~GEN01~Age-Standardized       2011           AL
# 4       BRFSS~2011~01~BR001~GEN02~Age-Standardized       2011           AL
# 13      BRFSS~2011~01~BR001~RAC01~Age-Standardized       2011           AL
# 14      BRFSS~2011~01~BR001~RAC02~Age-Standardized       2011           AL
# ...                                            ...        ...          ...
# 160151  BRFSS~2020~58~BR012~RAC01~Age-Standardized       2020          USM
# 160152  BRFSS~2020~58~BR012~RAC02~Age-Standardized       2020          USM
# 160155  BRFSS~2020~58~BR012~RAC03~Age-Standardized       2020          USM
# 160156  BRFSS~2020~58~BR012~RAC04~Age-Standardized       2020          USM
# 160159  BRFSS~2020~58~BR012~RAC07~Age-Standardized       2020          USM
#
# ...

# %%
cardio_df["Break_Out"].value_counts()
# Out:
# Overall               7280
# Male                  7280
# Female                7280
# Non-Hispanic White    7280
# Non-Hispanic Black    7280
# Non-Hispanic Asian    7280
# Hispanic              7280
# Other                 7280
# Name: Break_Out, dtype: int64

# %%
#remove US mean rows
cardio_df = cardio_df[cardio_df["LocationAbbr"] != 'USM']
cardio_df
# Out:
#                                              RowId  YearStart LocationAbbr  \
# 0       BRFSS~2011~01~BR001~OVR01~Age-Standardized       2011           AL
# 3       BRFSS~2011~01~BR001~GEN01~Age-Standardized       2011           AL
# 4       BRFSS~2011~01~BR001~GEN02~Age-Standardized       2011           AL
# 13      BRFSS~2011~01~BR001~RAC01~Age-Standardized       2011           AL
# 14      BRFSS~2011~01~BR001~RAC02~Age-Standardized       2011           AL
# ...                                            ...        ...          ...
# 160129  BRFSS~2020~56~BR012~RAC01~Age-Standardized       2020           WY
# 160130  BRFSS~2020~56~BR012~RAC02~Age-Standardized       2020           WY
# 160133  BRFSS~2020~56~BR012~RAC03~Age-Standardized       2020           WY
# 160134  BRFSS~2020~56~BR012~RAC04~Age-Standardized       2020           WY
# 160136  BRFSS~2020~56~BR012~RAC07~Age-Standardized       2020           WY
#
#        LocationDesc DataSource PriorityArea1  PriorityArea2  \
# ...

# %%
cardio_df = cardio_df[cardio_df["YearStart"] != 2020]
cardio_df
# Out:
#                                              RowId  YearStart LocationAbbr  \
# 0       BRFSS~2011~01~BR001~OVR01~Age-Standardized       2011           AL
# 3       BRFSS~2011~01~BR001~GEN01~Age-Standardized       2011           AL
# 4       BRFSS~2011~01~BR001~GEN02~Age-Standardized       2011           AL
# 13      BRFSS~2011~01~BR001~RAC01~Age-Standardized       2011           AL
# 14      BRFSS~2011~01~BR001~RAC02~Age-Standardized       2011           AL
# ...                                            ...        ...          ...
# 158985  BRFSS~2019~56~BR012~RAC01~Age-Standardized       2019           WY
# 158986  BRFSS~2019~56~BR012~RAC02~Age-Standardized       2019           WY
# 158989  BRFSS~2019~56~BR012~RAC03~Age-Standardized       2019           WY
# 158990  BRFSS~2019~56~BR012~RAC04~Age-Standardized       2019           WY
# 158993  BRFSS~2019~56~BR012~RAC07~Age-Standardized       2019           WY
#
#        LocationDesc DataSource PriorityArea1  PriorityArea2  \
# ...

# %%
cardio_df = cardio_df.drop(columns = ["RowId","DataSource", "Class","Topic","LocationDesc", "PriorityArea1", "PriorityArea2", "PriorityArea3", "PriorityArea4", "Data_Value_Alt", "Data_Value_Unit", "Data_Value_TypeID", "Data_Value_Footnote_Symbol", "ClassId","TopicId","QuestionId","BreakOutCategoryId", "BreakOutId","LocationId", "Geolocation", "Data_Value_Footnote", "Low_Confidence_Limit", "High_Confidence_Limit"])
cardio_df
# Out:
#         YearStart LocationAbbr  \
# 0            2011           AL
# 3            2011           AL
# 4            2011           AL
# 13           2011           AL
# 14           2011           AL
# ...           ...          ...
# 158985       2019           WY
# 158986       2019           WY
# 158989       2019           WY
# 158990       2019           WY
# 158993       2019           WY
#
#                                                  Question   Data_Value_Type  \
# 0       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 3       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 4       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 13      Prevalence of major cardiovascular disease amo...  Age-Standardized
# 14      Prevalence of major cardiovascular disease amo...  Age-Standardized
# ...                                                   ...               ...
# ...

# %%
cardio_df = cardio_df[cardio_df['Data_Value'].notna()]
cardio_df
# Out:
#         YearStart LocationAbbr  \
# 0            2011           AL
# 3            2011           AL
# 4            2011           AL
# 13           2011           AL
# 14           2011           AL
# ...           ...          ...
# 158976       2019           WY
# 158985       2019           WY
# 158986       2019           WY
# 158989       2019           WY
# 158990       2019           WY
#
#                                                  Question   Data_Value_Type  \
# 0       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 3       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 4       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 13      Prevalence of major cardiovascular disease amo...  Age-Standardized
# 14      Prevalence of major cardiovascular disease amo...  Age-Standardized
# ...                                                   ...               ...
# ...

# %%
cardio_df = cardio_df[cardio_df['Break_Out_Category'].isin(['Overall','Gender'])]
cardio_df
# Out:
#         YearStart LocationAbbr  \
# 0            2011           AL
# 3            2011           AL
# 4            2011           AL
# 22           2011           AK
# 25           2011           AK
# ...           ...          ...
# 158953       2019           WI
# 158954       2019           WI
# 158972       2019           WY
# 158975       2019           WY
# 158976       2019           WY
#
#                                                  Question   Data_Value_Type  \
# 0       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 3       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 4       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 22      Prevalence of major cardiovascular disease amo...  Age-Standardized
# 25      Prevalence of major cardiovascular disease amo...  Age-Standardized
# ...                                                   ...               ...
# ...

# %%
cardio_df["Question"].value_counts()
# Out:
# Prevalence of major cardiovascular disease among US adults (18+); BRFSS                                  1221
# Prevalence of acute myocardial infarction (heart attack) among US adults (18+); BRFSS                    1221
# Prevalence of coronary heart disease among US adults (18+); BRFSS                                        1221
# Prevalence of stroke among US adults (18+); BRFSS                                                        1221
# Prevalence of diabetes among US adults (18+); BRFSS                                                      1221
# Prevalence of obesity among US adults (20+); BRFSS                                                       1221
# Prevalence of physical inactivity among US adults (18+); BRFSS                                           1221
# Prevalence of current smoking among US adults (18+); BRFSS                                               1221
# ...

# %%
cardio_df = cardio_df[cardio_df['Question'].isin(['Prevalence of major cardiovascular disease among US adults (18+); BRFSS',
                                                  'Prevalence of acute myocardial infarction (heart attack) among US adults (18+); BRFSS',
                                                 'Prevalence of coronary heart disease among US adults (18+); BRFSS',
                                                 'Prevalence of stroke among US adults (18+); BRFSS',
                                                 'Prevalence of diabetes among US adults (18+); BRFSS',
                                                 'Prevalence of obesity among US adults (20+); BRFSS',
                                                 'Prevalence of physical inactivity among US adults (18+); BRFSS',
                                                 'Prevalence of physical inactivity among US adults (18+); BRFSS',
                                                 'Prevalence of physical inactivity among US adults (18+); BRFSS'])]
cardio_df
# Out:
#         YearStart LocationAbbr  \
# 0            2011           AL
# 3            2011           AL
# 4            2011           AL
# 22           2011           AK
# 25           2011           AK
# ...           ...          ...
# 124633       2019           WI
# 124634       2019           WI
# 124652       2019           WY
# 124655       2019           WY
# 124656       2019           WY
#
#                                                  Question   Data_Value_Type  \
# 0       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 3       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 4       Prevalence of major cardiovascular disease amo...  Age-Standardized
# 22      Prevalence of major cardiovascular disease amo...  Age-Standardized
# 25      Prevalence of major cardiovascular disease amo...  Age-Standardized
# ...                                                   ...               ...
# ...

# %%
cardio_df["Question"].value_counts()
# Out:
# Prevalence of major cardiovascular disease among US adults (18+); BRFSS                  1221
# Prevalence of acute myocardial infarction (heart attack) among US adults (18+); BRFSS    1221
# Prevalence of coronary heart disease among US adults (18+); BRFSS                        1221
# Prevalence of stroke among US adults (18+); BRFSS                                        1221
# Prevalence of diabetes among US adults (18+); BRFSS                                      1221
# Prevalence of obesity among US adults (20+); BRFSS                                       1221
# Prevalence of physical inactivity among US adults (18+); BRFSS                           1221
# Name: Question, dtype: int64

# %%
cardio_df['YearStart'] = cardio_df['YearStart'].astype(str)
cardio_df['Year-State'] = cardio_df['YearStart'] + '-' + cardio_df['LocationAbbr']
cardio_df.head()
# Out:
# C:\Users\Cody\AppData\Local\Temp\ipykernel_20712\997709564.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cardio_df['YearStart'] = cardio_df['YearStart'].astype(str)
# C:\Users\Cody\AppData\Local\Temp\ipykernel_20712\997709564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cardio_df['Year-State'] = cardio_df['YearStart'] + '-' + cardio_df['LocationAbbr']
#    YearStart LocationAbbr                                           Question  \
# ...

# %%
year_state_list = []
for index,row in cardio_df.iterrows():
    year_state = row['Year-State']
    if year_state not in year_state_list:
        year_state_list.append(year_state)

# %%
major_cvd_overall = []
major_cvd_male = []
major_cvd_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of major cardiovascular disease among US adults (18+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            major_cvd_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            major_cvd_male.append(value)
        else:
            value = row['Data_Value'] 
            major_cvd_female.append(value)

# %%
heart_attack_overall = []
heart_attack_male = []
heart_attack_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of acute myocardial infarction (heart attack) among US adults (18+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            heart_attack_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            heart_attack_male.append(value)
        else:
            value = row['Data_Value'] 
            heart_attack_female.append(value)

# %%
chd_overall = []
chd_male = []
chd_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of coronary heart disease among US adults (18+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            chd_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            chd_male.append(value)
        else:
            value = row['Data_Value'] 
            chd_female.append(value)

# %%
stroke_overall = []
stroke_male = []
stroke_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of stroke among US adults (18+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            stroke_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            stroke_male.append(value)
        else:
            value = row['Data_Value'] 
            stroke_female.append(value)

# %%
diabetes_overall = []
diabetes_male = []
diabetes_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of diabetes among US adults (18+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            diabetes_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            diabetes_male.append(value)
        else:
            value = row['Data_Value'] 
            diabetes_female.append(value)

# %%
obesity_overall = []
obesity_male = []
obesity_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of obesity among US adults (20+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            obesity_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            obesity_male.append(value)
        else:
            value = row['Data_Value'] 
            obesity_female.append(value)

# %%
physical_inactive_overall = []
physical_inactive_male = []
pysical_inactive_female = []

for index,row in cardio_df.iterrows():
    if row['Question'] == "Prevalence of physical inactivity among US adults (18+); BRFSS":
        if row['Break_Out'] == 'Overall':        
            value = row['Data_Value'] 
            physical_inactive_overall.append(value)
        elif row['Break_Out'] == 'Male':
            value = row['Data_Value'] 
            physical_inactive_male.append(value)
        else:
            value = row['Data_Value'] 
            pysical_inactive_female.append(value)

# %%
test_df = pd.DataFrame({"Year-State": year_state_list,
                        "Inactive-Female": pysical_inactive_female,
                       "Inactive-Male": physical_inactive_male, 
                       "Inactive-Overall":physical_inactive_overall,
                       "Obese-Female": obesity_female,
                       "Obese-Male": obesity_male,
                       "Obese-Overall":obesity_overall,
                       "Diabetic-Female": diabetes_female,
                       "Diabetic-Male": diabetes_male,
                       "Diabetic-Overall": diabetes_overall,
                       "Stroke-Female": stroke_female,
                       "Stroke-Male": stroke_male,
                       "Stroke-Overall": stroke_overall,
                       "Coronary Disease-Female": chd_female,
                       "Coronary Disease-Male": chd_male,
                       "Coronary Disease-Overall": chd_overall,
                       "Heart Attack-Female":heart_attack_female,
                       "Heart Attack-Male":heart_attack_male,
                       "Heart Attack-Overall":major_cvd_overall,
                       "Major CV Disease-Female":major_cvd_female,
                       "Major CV Disease-Male":major_cvd_male,
                       "Major CV Disease-Overall":major_cvd_overall}) 
test_df
# Out:
#     Year-State  Inactive-Female  Inactive-Male  Inactive-Overall  \
# 0      2011-AL             65.7           70.6              68.0
# 1      2011-AK             75.8           79.8              77.9
# 2      2011-AZ             75.9           76.3              76.1
# 3      2011-AR             67.2           72.9              70.0
# 4      2011-CA             80.1           81.8              80.9
# ..         ...              ...            ...               ...
# 402    2019-VA             73.8           76.8              75.3
# 403    2019-WA             80.7           81.5              81.1
# 404    2019-WV             68.5           73.0              70.7
# 405    2019-WI             75.0           79.9              77.4
# 406    2019-WY             77.2           75.0              76.1
#
#      Obese-Female  Obese-Male  Obese-Overall  Diabetic-Female  Diabetic-Male  \
# 0            32.9        32.9           32.9             11.4           10.4
# ...

# %%
len(year_state)
# Out:
# 7
