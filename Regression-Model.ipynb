# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
import sklearn as skl
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#import data
merged_df=pd.read_csv(Path('CV_cigaretee.csv'))

# %%
merged_df.head()
# Out:
#   Year-State  Inactive-Female  Inactive-Male  Inactive-Overall  Obese-Female  \
# 0    2011-AL             65.7           70.6              68.0          32.9
# 1    2011-AK             75.8           79.8              77.9          27.6
# 2    2011-AZ             75.9           76.3              76.1          26.7
# 3    2011-AR             67.2           72.9              70.0          32.4
# 4    2011-CA             80.1           81.8              80.9          25.1
#
#    Obese-Male  Obese-Overall  Diabetic-Female  Diabetic-Male  \
# 0        32.9           32.9             11.4           10.4
# 1        28.6           28.1              8.6            8.1
# 2        24.9           25.7              8.1           10.0
# 3        31.0           31.6              9.7           11.2
# 4        23.9           24.6              7.9            9.2
#
#    Diabetic-Overall  ...  Major CV Disease-Overall  current_overall  \
# 0              10.8  ...                       9.9             24.3
# 1               8.4  ...                       6.5             22.9
# 2               9.0  ...                       7.8             19.3
# 3              10.4  ...                       9.8             27.0
# 4               8.4  ...                       6.6             13.7
#
#    current_female  current_male  Never_overall  Never_female  Never_male  \
# 0            21.0          28.0           50.6          58.8        41.5
# 1            23.0          22.9           49.1          52.2        46.2
# 2            17.5          21.0           55.9          61.3        50.3
# 3            25.2          28.9           47.9          53.0        42.6
# 4            10.0          17.3           62.5          70.1        54.8
#
#    Former_overall  Former_female  Former_male
# 0            25.1           20.1         30.5
# 1            27.9           24.9         30.8
# 2            24.9           21.1         28.7
# 3            25.1           21.8         28.6
# 4            23.9           19.9         27.9
#
# [5 rows x 31 columns]

# %%
# define X (inputs) and y (target/output)
X = merged_df.drop(columns = ["Year-State","Major CV Disease-Overall"], axis=1)
y = merged_df[['Major CV Disease-Overall']]

# %%
print(X.shape, y.shape)
# Out:
# (407, 29) (407, 1)

# %%
X = np.array(X)
y = np.array(y)

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (305, 29) (102, 29) (305, 1) (102, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
# Create scaler instance
min_max_scaler = MinMaxScaler()

X_scaler = min_max_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=29))

# %%
# Add our hidden layer layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu"))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 5)                 150
#
#  dense_28 (Dense)            (None, 5)                 30
#
#  dense_29 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 186 (744.00 Byte)
# Trainable params: 186 (744.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# Fit the model to the training data
fit_model = nn_model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    epochs=100,
                    verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 15ms/step - loss: 26.1686 - mae: 4.0185 - val_loss: 8.7816 - val_mae: 2.3471
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.7447 - mae: 2.2975 - val_loss: 8.0756 - val_mae: 2.1481
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 7.3438 - mae: 2.0883 - val_loss: 7.0434 - val_mae: 1.9969
# Epoch 4/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.1845 - mae: 1.9316 - val_loss: 5.6815 - val_mae: 1.8244
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 5.3558 - mae: 1.7715 - val_loss: 5.6736 - val_mae: 1.7674
# Epoch 6/100
# 10/10 [==============================] - 0s 6ms/step - loss: 4.6532 - mae: 1.6370 - val_loss: 4.4391 - val_mae: 1.7283
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 4.1009 - mae: 1.5661 - val_loss: 3.6987 - val_mae: 1.5389
# Epoch 8/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.6978 - mae: 1.4671 - val_loss: 3.7489 - val_mae: 1.4327
# Epoch 9/100
# 10/10 [==============================] - 0s 6ms/step - loss: 3.1152 - mae: 1.3546 - val_loss: 2.9003 - val_mae: 1.3461
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.6992 - mae: 1.2446 - val_loss: 4.0628 - val_mae: 1.4980
# Epoch 11/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.4459 - mae: 1.2007 - val_loss: 2.2029 - val_mae: 1.1456
# Epoch 12/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0974 - mae: 1.1154 - val_loss: 2.2703 - val_mae: 1.1217
# Epoch 13/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8632 - mae: 1.0373 - val_loss: 1.5383 - val_mae: 0.9515
# Epoch 14/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5807 - mae: 0.9721 - val_loss: 1.4346 - val_mae: 0.9127
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.4815 - mae: 0.9313 - val_loss: 1.3264 - val_mae: 0.9035
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.4009 - mae: 0.9188 - val_loss: 1.6136 - val_mae: 0.9035
# Epoch 17/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2805 - mae: 0.8706 - val_loss: 1.2253 - val_mae: 0.8831
# Epoch 18/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3876 - mae: 0.9029 - val_loss: 1.2592 - val_mae: 0.9363
# Epoch 19/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1612 - mae: 0.8175 - val_loss: 1.0857 - val_mae: 0.7918
# Epoch 20/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1266 - mae: 0.7989 - val_loss: 1.6109 - val_mae: 0.9018
# Epoch 21/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1237 - mae: 0.8141 - val_loss: 1.4850 - val_mae: 1.0330
# Epoch 22/100
# 10/10 [==============================] - 0s 6ms/step - loss: 1.0554 - mae: 0.7897 - val_loss: 1.0837 - val_mae: 0.7430
# Epoch 23/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9586 - mae: 0.7404 - val_loss: 0.9858 - val_mae: 0.7306
# Epoch 24/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.9518 - mae: 0.7378 - val_loss: 0.9278 - val_mae: 0.7201
# Epoch 25/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8870 - mae: 0.7161 - val_loss: 0.8977 - val_mae: 0.7432
# Epoch 26/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8803 - mae: 0.7232 - val_loss: 1.0397 - val_mae: 0.7285
# Epoch 27/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8790 - mae: 0.7099 - val_loss: 0.9232 - val_mae: 0.7954
# Epoch 28/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8298 - mae: 0.6883 - val_loss: 0.8659 - val_mae: 0.6664
# Epoch 29/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.8386 - mae: 0.7058 - val_loss: 0.8027 - val_mae: 0.6623
# Epoch 30/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7440 - mae: 0.6593 - val_loss: 0.8391 - val_mae: 0.7671
# Epoch 31/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7203 - mae: 0.6384 - val_loss: 0.7777 - val_mae: 0.7264
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7820 - mae: 0.6805 - val_loss: 0.7786 - val_mae: 0.7350
# Epoch 33/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6946 - mae: 0.6475 - val_loss: 0.7885 - val_mae: 0.7387
# Epoch 34/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7774 - mae: 0.6743 - val_loss: 0.8384 - val_mae: 0.6654
# Epoch 35/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6683 - mae: 0.6283 - val_loss: 0.7212 - val_mae: 0.6204
# Epoch 36/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6538 - mae: 0.6259 - val_loss: 0.9949 - val_mae: 0.8500
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6642 - mae: 0.6266 - val_loss: 0.6848 - val_mae: 0.6714
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7480 - mae: 0.6751 - val_loss: 0.6895 - val_mae: 0.6049
# Epoch 39/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6122 - mae: 0.6027 - val_loss: 0.7441 - val_mae: 0.6529
# Epoch 40/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6925 - mae: 0.6283 - val_loss: 0.6338 - val_mae: 0.6442
# Epoch 41/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7045 - mae: 0.6436 - val_loss: 0.6116 - val_mae: 0.5902
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6014 - mae: 0.6105 - val_loss: 0.6051 - val_mae: 0.6166
# Epoch 43/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6115 - mae: 0.6011 - val_loss: 0.7392 - val_mae: 0.6602
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6272 - mae: 0.6124 - val_loss: 0.7148 - val_mae: 0.7138
# Epoch 45/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5738 - mae: 0.5897 - val_loss: 0.6460 - val_mae: 0.5906
# Epoch 46/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5740 - mae: 0.6025 - val_loss: 0.5648 - val_mae: 0.6008
# Epoch 47/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6367 - mae: 0.6318 - val_loss: 0.6121 - val_mae: 0.6009
# Epoch 48/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6229 - mae: 0.6192 - val_loss: 0.5748 - val_mae: 0.5624
# Epoch 49/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5106 - mae: 0.5464 - val_loss: 0.6972 - val_mae: 0.6544
# Epoch 50/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5845 - mae: 0.5969 - val_loss: 0.5212 - val_mae: 0.5573
# Epoch 51/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5456 - mae: 0.5756 - val_loss: 0.5198 - val_mae: 0.5497
# Epoch 52/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5646 - mae: 0.5852 - val_loss: 0.6770 - val_mae: 0.7009
# Epoch 53/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5785 - mae: 0.5955 - val_loss: 0.5503 - val_mae: 0.6097
# Epoch 54/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5009 - mae: 0.5554 - val_loss: 0.5790 - val_mae: 0.6339
# Epoch 55/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5734 - mae: 0.5962 - val_loss: 0.5127 - val_mae: 0.5411
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4681 - mae: 0.5194 - val_loss: 0.6874 - val_mae: 0.7087
# Epoch 57/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6016 - mae: 0.6161 - val_loss: 0.5038 - val_mae: 0.5763
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5010 - mae: 0.5509 - val_loss: 0.4836 - val_mae: 0.5439
# Epoch 59/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4846 - mae: 0.5335 - val_loss: 0.5967 - val_mae: 0.6132
# Epoch 60/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4814 - mae: 0.5373 - val_loss: 0.5123 - val_mae: 0.5960
# Epoch 61/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5157 - mae: 0.5657 - val_loss: 0.4646 - val_mae: 0.5331
# Epoch 62/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4777 - mae: 0.5447 - val_loss: 0.4820 - val_mae: 0.5665
# Epoch 63/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5088 - mae: 0.5569 - val_loss: 0.4737 - val_mae: 0.5643
# Epoch 64/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5527 - mae: 0.5642 - val_loss: 0.4449 - val_mae: 0.5127
# Epoch 65/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4388 - mae: 0.5143 - val_loss: 0.5076 - val_mae: 0.5507
# Epoch 66/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5125 - mae: 0.5643 - val_loss: 0.7208 - val_mae: 0.6859
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5051 - mae: 0.5684 - val_loss: 0.4453 - val_mae: 0.5105
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4624 - mae: 0.5292 - val_loss: 0.8582 - val_mae: 0.7942
# Epoch 69/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5300 - mae: 0.5779 - val_loss: 0.4849 - val_mae: 0.5459
# Epoch 70/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4711 - mae: 0.5430 - val_loss: 0.4175 - val_mae: 0.5039
# Epoch 71/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4915 - mae: 0.5555 - val_loss: 0.4678 - val_mae: 0.5724
# Epoch 72/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4447 - mae: 0.5216 - val_loss: 0.4090 - val_mae: 0.5038
# Epoch 73/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4414 - mae: 0.5220 - val_loss: 0.4503 - val_mae: 0.5236
# Epoch 74/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4835 - mae: 0.5477 - val_loss: 0.4303 - val_mae: 0.5432
# Epoch 75/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3910 - mae: 0.4950 - val_loss: 0.5353 - val_mae: 0.5951
# Epoch 76/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5100 - mae: 0.5482 - val_loss: 0.3910 - val_mae: 0.4908
# Epoch 77/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4090 - mae: 0.4977 - val_loss: 0.4599 - val_mae: 0.5473
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4373 - mae: 0.5266 - val_loss: 0.4595 - val_mae: 0.5323
# Epoch 79/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4318 - mae: 0.5110 - val_loss: 0.4292 - val_mae: 0.5029
# Epoch 80/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4355 - mae: 0.5133 - val_loss: 0.4059 - val_mae: 0.5090
# Epoch 81/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4108 - mae: 0.5137 - val_loss: 0.5670 - val_mae: 0.6358
# Epoch 82/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3833 - mae: 0.4823 - val_loss: 0.6755 - val_mae: 0.6701
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4257 - mae: 0.5163 - val_loss: 0.3540 - val_mae: 0.4845
# Epoch 84/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4470 - mae: 0.5264 - val_loss: 0.5761 - val_mae: 0.6182
# Epoch 85/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3938 - mae: 0.4942 - val_loss: 0.3050 - val_mae: 0.4628
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4060 - mae: 0.4986 - val_loss: 0.3273 - val_mae: 0.4753
# Epoch 87/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3615 - mae: 0.4845 - val_loss: 0.3565 - val_mae: 0.4843
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4066 - mae: 0.5062 - val_loss: 0.4034 - val_mae: 0.5152
# Epoch 89/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3451 - mae: 0.4573 - val_loss: 0.3375 - val_mae: 0.4785
# Epoch 90/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3959 - mae: 0.4960 - val_loss: 0.2678 - val_mae: 0.4292
# Epoch 91/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3479 - mae: 0.4592 - val_loss: 0.3551 - val_mae: 0.4835
# Epoch 92/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3261 - mae: 0.4503 - val_loss: 0.3273 - val_mae: 0.4677
# Epoch 93/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3804 - mae: 0.4866 - val_loss: 0.2768 - val_mae: 0.4336
# Epoch 94/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3070 - mae: 0.4356 - val_loss: 0.3456 - val_mae: 0.4899
# Epoch 95/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3026 - mae: 0.4168 - val_loss: 0.2484 - val_mae: 0.4065
# Epoch 96/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3783 - mae: 0.4813 - val_loss: 0.2197 - val_mae: 0.3818
# Epoch 97/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2929 - mae: 0.4156 - val_loss: 0.2709 - val_mae: 0.4258
# Epoch 98/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3150 - mae: 0.4441 - val_loss: 0.3167 - val_mae: 0.4629
# Epoch 99/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2661 - mae: 0.4094 - val_loss: 0.2062 - val_mae: 0.3711
# Epoch 100/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3238 - mae: 0.4443 - val_loss: 0.2116 - val_mae: 0.3772

# %%
history_dict = fit_model.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=nn_model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=nn_model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()
# Out:
# 10/10 [==============================] - 0s 889us/step
# 4/4 [==============================] - 0s 1ms/step

# %%
# metrics
pred = nn_model.predict(X_test)
pred

trainpreds = nn_model.predict(X_train)

from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_train, trainpreds)) # train
print(mean_absolute_error(y_test, pred)) # test
# Out:
# 4/4 [==============================] - 0s 996us/step
# 10/10 [==============================] - 0s 997us/step
# 0.37921044584180486
# 0.37717863718668615

# %%
# Evaluate the model using the test data
#model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
#print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - loss: 0.0714 - accuracy: 0.0000e+00 - 78ms/epoch - 19ms/step
# Loss: 0.07142380625009537, Accuracy: 0.0

# %%
# if needed can create second model to try and optimize
