# %%
import pandas as pd
from pathlib import Path

# %%
merged_df=pd.read_csv(Path('CV_cigaretee.csv'))

# %%
target = []  # Initialize the target list
mean_value = merged_df["Major CV Disease-Overall"].mean()

for index, row in merged_df.iterrows():
    if row["Major CV Disease-Overall"] > mean_value:
        value = 1
        target.append(value)
    else:
        value = 0  # You might want to assign a different value for the other case
        target.append(value)
merged_df["target"] =target

# %%
y = merged_df["target"].values
X = merged_df.drop(columns = ["Year-State","target","Major CV Disease-Overall"])

# %%
# Use sklearn to split dataset
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Scale the input data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Add our first Dense layer, including the input layer

nn_model.add(tf.keras.layers.Dense(units=50, activation="relu", input_dim=29))
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_70 (Dense)            (None, 50)                1500
#
#  dense_71 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 1551 (6.06 KB)
# Trainable params: 1551 (6.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3040 - accuracy: 0.4426
# Epoch 2/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1608 - accuracy: 0.8197
# Epoch 3/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9344
# Epoch 4/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9508
# Epoch 5/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9541
# Epoch 6/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9541
# Epoch 7/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9574
# Epoch 8/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 0.9574
# Epoch 9/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9574
# Epoch 10/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9574
# Epoch 11/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9574
# Epoch 12/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9607
# Epoch 13/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9639
# Epoch 14/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9672
# Epoch 15/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9672
# Epoch 16/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9672
# Epoch 17/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9672
# Epoch 18/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9672
# Epoch 19/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9672
# Epoch 20/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9672
# Epoch 21/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9705
# Epoch 22/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 0.9705
# Epoch 23/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9705
# Epoch 24/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9705
# Epoch 25/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9705
# Epoch 26/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9705
# Epoch 27/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9705
# Epoch 28/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9705
# Epoch 29/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9705
# Epoch 30/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9705
# Epoch 31/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9705
# Epoch 32/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9738
# Epoch 33/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 0.9738
# Epoch 34/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9738
# Epoch 35/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9738
# Epoch 36/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9803
# Epoch 37/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9836
# Epoch 38/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 0.9836
# Epoch 39/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 0.9836
# Epoch 40/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9836
# Epoch 41/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9836
# Epoch 42/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9836
# Epoch 43/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9836
# Epoch 44/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9869
# Epoch 45/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 0.9902
# Epoch 46/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9902
# Epoch 47/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9934
# Epoch 48/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.9934
# Epoch 49/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9934
# Epoch 50/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.9934
# 4/4 - 0s - loss: 0.0422 - accuracy: 0.9216 - 143ms/epoch - 36ms/step
# Loss: 0.04220889136195183, Accuracy: 0.9215686321258545

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - loss: 0.0422 - accuracy: 0.9216 - 32ms/epoch - 8ms/step
# Loss: 0.04220889136195183, Accuracy: 0.9215686321258545

# %%
# only use the cigaretee data
y = merged_df["target"].values
X = merged_df.drop(columns = ["Year-State","target","Major CV Disease-Overall",'Inactive-Female', 'Inactive-Male', 'Inactive-Overall',
       'Obese-Female', 'Obese-Male', 'Obese-Overall', 'Diabetic-Female',
       'Diabetic-Male', 'Diabetic-Overall', 'Stroke-Female', 'Stroke-Male',
       'Stroke-Overall', 'Coronary Disease-Female', 'Coronary Disease-Male',
       'Coronary Disease-Overall', 'Heart Attack-Female', 'Heart Attack-Male',
       'Heart Attack-Overall', 'Major CV Disease-Female',
       'Major CV Disease-Male'])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Add our first Dense layer, including the input layer

nn_model.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=9))
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=9))
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 2ms/step - loss: 0.2212 - accuracy: 0.7148
# Epoch 2/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1768 - accuracy: 0.8262
# Epoch 3/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1527 - accuracy: 0.8262
# Epoch 4/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.8230
# Epoch 5/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1332 - accuracy: 0.8295
# Epoch 6/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.8295
# Epoch 7/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.8262
# Epoch 8/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1239 - accuracy: 0.8197
# Epoch 9/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8230
# Epoch 10/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.8230
# Epoch 11/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1199 - accuracy: 0.8197
# Epoch 12/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.8230
# Epoch 13/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.8230
# Epoch 14/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.8197
# Epoch 15/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.8230
# Epoch 16/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.8262
# Epoch 17/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1149 - accuracy: 0.8361
# Epoch 18/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 0.8361
# Epoch 19/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.8361
# Epoch 20/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 0.8361
# Epoch 21/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.8426
# Epoch 22/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1118 - accuracy: 0.8426
# Epoch 23/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1113 - accuracy: 0.8393
# Epoch 24/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1110 - accuracy: 0.8426
# Epoch 25/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1099 - accuracy: 0.8426
# Epoch 26/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.8459
# Epoch 27/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.8426
# Epoch 28/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.8426
# Epoch 29/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1082 - accuracy: 0.8393
# Epoch 30/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.8492
# Epoch 31/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.8393
# Epoch 32/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1067 - accuracy: 0.8426
# Epoch 33/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 0.8361
# Epoch 34/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1057 - accuracy: 0.8426
# Epoch 35/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1054 - accuracy: 0.8426
# Epoch 36/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.8426
# Epoch 37/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.8459
# Epoch 38/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1044 - accuracy: 0.8459
# Epoch 39/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.8426
# Epoch 40/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.8459
# Epoch 41/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1037 - accuracy: 0.8459
# Epoch 42/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.8426
# Epoch 43/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.8393
# Epoch 44/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.8426
# Epoch 45/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.8459
# Epoch 46/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 0.8492
# Epoch 47/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.8492
# Epoch 48/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 0.8492
# Epoch 49/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.8459
# Epoch 50/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.8492
# 4/4 - 0s - loss: 0.1243 - accuracy: 0.7843 - 155ms/epoch - 39ms/step
# Loss: 0.12426700443029404, Accuracy: 0.7843137383460999
