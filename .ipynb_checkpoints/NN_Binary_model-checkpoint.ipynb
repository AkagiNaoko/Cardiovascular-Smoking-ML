# %%
import pandas as pd
from pathlib import Path

# %%
merged_df=pd.read_csv(Path('Resources\Outputs\CV_cigaretee.csv'))

# %%
target = []  # Initialize the target list
mean_value = merged_df["Major CV Disease-Overall"].mean()

for index, row in merged_df.iterrows():
    if row["Major CV Disease-Overall"] > mean_value:
        value = 1
        target.append(value)
    else:
        value = 0  # You might want to assign a different value for the other case
        target.append(value)
merged_df["target"] =target

# %%
y = merged_df["target"].values
X = merged_df.drop(columns = ["Year-State","target","Major CV Disease-Overall"])

# %%
# Use sklearn to split dataset
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Scale the input data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Add our first Dense layer, including the input layer

nn_model.add(tf.keras.layers.Dense(units=50, activation="relu", input_dim=29))
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                1500
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 1551 (6.06 KB)
# Trainable params: 1551 (6.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2575 - accuracy: 0.5574
# Epoch 2/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1518 - accuracy: 0.7639
# Epoch 3/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9016
# Epoch 4/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0710 - accuracy: 0.9279
# Epoch 5/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9410
# Epoch 6/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 0.9443
# Epoch 7/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0504 - accuracy: 0.9508
# Epoch 8/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0467 - accuracy: 0.9541
# Epoch 9/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9541
# Epoch 10/50
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9574
# Epoch 11/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0391 - accuracy: 0.9574
# Epoch 12/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.0371 - accuracy: 0.9574
# Epoch 13/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 0.9574
# Epoch 14/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 0.9574
# Epoch 15/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9607
# Epoch 16/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 0.9672
# Epoch 17/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 0.9705
# Epoch 18/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 0.9705
# Epoch 19/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 0.9705
# Epoch 20/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 0.9738
# Epoch 21/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 0.9738
# Epoch 22/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0241 - accuracy: 0.9738
# Epoch 23/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.0230 - accuracy: 0.9738
# Epoch 24/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0222 - accuracy: 0.9738
# Epoch 25/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0214 - accuracy: 0.9738
# Epoch 26/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 0.9738
# Epoch 27/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 0.9738
# Epoch 28/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 0.9738
# Epoch 29/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9803
# Epoch 30/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0179 - accuracy: 0.9836
# Epoch 31/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 0.9869
# Epoch 32/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 0.9869
# Epoch 33/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 0.9902
# Epoch 34/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0156 - accuracy: 0.9869
# Epoch 35/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.0151 - accuracy: 0.9869
# Epoch 36/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 0.9902
# Epoch 37/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 0.9934
# Epoch 38/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.0137 - accuracy: 0.9934
# Epoch 39/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 0.9934
# Epoch 40/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9967
# Epoch 41/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 0.9967
# Epoch 42/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 0.9967
# Epoch 43/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.9967
# Epoch 44/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 0.9967
# Epoch 45/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 0.9967
# Epoch 46/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 0.9967
# Epoch 47/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.9967
# Epoch 48/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.9967
# Epoch 49/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0097 - accuracy: 0.9967
# Epoch 50/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.0095 - accuracy: 0.9967
# 4/4 - 0s - loss: 0.0382 - accuracy: 0.9412 - 105ms/epoch - 26ms/step
# Loss: 0.03816211596131325, Accuracy: 0.9411764740943909

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - loss: 0.0382 - accuracy: 0.9412 - 17ms/epoch - 4ms/step
# Loss: 0.03816211596131325, Accuracy: 0.9411764740943909

# %%
# only use the cigaretee data
y = merged_df["target"].values
X = merged_df.drop(columns = ["Year-State","target","Major CV Disease-Overall",'Inactive-Female', 'Inactive-Male', 'Inactive-Overall',
       'Obese-Female', 'Obese-Male', 'Obese-Overall', 'Diabetic-Female',
       'Diabetic-Male', 'Diabetic-Overall', 'Stroke-Female', 'Stroke-Male',
       'Stroke-Overall', 'Coronary Disease-Female', 'Coronary Disease-Male',
       'Coronary Disease-Overall', 'Heart Attack-Female', 'Heart Attack-Male',
       'Heart Attack-Overall', 'Major CV Disease-Female',
       'Major CV Disease-Male'])
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Add our first Dense layer, including the input layer

nn_model.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=9))
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=9))
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 1ms/step - loss: 0.2374 - accuracy: 0.5246
# Epoch 2/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1968 - accuracy: 0.8000
# Epoch 3/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.8131
# Epoch 4/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.1543 - accuracy: 0.8033
# Epoch 5/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1429 - accuracy: 0.8164
# Epoch 6/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1354 - accuracy: 0.8197
# Epoch 7/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1299 - accuracy: 0.8197
# Epoch 8/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1266 - accuracy: 0.8197
# Epoch 9/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1242 - accuracy: 0.8197
# Epoch 10/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1221 - accuracy: 0.8230
# Epoch 11/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.1207 - accuracy: 0.8295
# Epoch 12/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.1195 - accuracy: 0.8262
# Epoch 13/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.1183 - accuracy: 0.8295
# Epoch 14/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1174 - accuracy: 0.8230
# Epoch 15/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1167 - accuracy: 0.8262
# Epoch 16/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.8230
# Epoch 17/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1148 - accuracy: 0.8197
# Epoch 18/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.1142 - accuracy: 0.8262
# Epoch 19/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.8295
# Epoch 20/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1127 - accuracy: 0.8328
# Epoch 21/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.8393
# Epoch 22/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1114 - accuracy: 0.8393
# Epoch 23/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1106 - accuracy: 0.8361
# Epoch 24/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1102 - accuracy: 0.8393
# Epoch 25/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1094 - accuracy: 0.8393
# Epoch 26/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1087 - accuracy: 0.8328
# Epoch 27/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1083 - accuracy: 0.8328
# Epoch 28/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1073 - accuracy: 0.8328
# Epoch 29/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1068 - accuracy: 0.8361
# Epoch 30/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1061 - accuracy: 0.8361
# Epoch 31/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1055 - accuracy: 0.8361
# Epoch 32/50
# 10/10 [==============================] - 0s 997us/step - loss: 0.1051 - accuracy: 0.8393
# Epoch 33/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.8393
# Epoch 34/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.8426
# Epoch 35/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1036 - accuracy: 0.8426
# Epoch 36/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 0.8492
# Epoch 37/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1027 - accuracy: 0.8492
# Epoch 38/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1022 - accuracy: 0.8459
# Epoch 39/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 0.8459
# Epoch 40/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 0.8361
# Epoch 41/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1012 - accuracy: 0.8393
# Epoch 42/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.8393
# Epoch 43/50
# 10/10 [==============================] - 0s 995us/step - loss: 0.0996 - accuracy: 0.8426
# Epoch 44/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0994 - accuracy: 0.8393
# Epoch 45/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0988 - accuracy: 0.8426
# Epoch 46/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0982 - accuracy: 0.8393
# Epoch 47/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0980 - accuracy: 0.8393
# Epoch 48/50
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0977 - accuracy: 0.8393
# Epoch 49/50
# 10/10 [==============================] - 0s 886us/step - loss: 0.0973 - accuracy: 0.8393
# Epoch 50/50
# 10/10 [==============================] - 0s 1000us/step - loss: 0.0969 - accuracy: 0.8393
# 4/4 - 0s - loss: 0.1265 - accuracy: 0.7843 - 78ms/epoch - 19ms/step
# Loss: 0.12649081647396088, Accuracy: 0.7843137383460999
