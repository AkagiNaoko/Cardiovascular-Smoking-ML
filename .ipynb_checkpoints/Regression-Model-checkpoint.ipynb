# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
import sklearn as skl
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#import data
merged_df=pd.read_csv(Path('CV_cigaretee.csv'))

# %%
merged_df.head()
# Out:
#   Year-State  Inactive-Female  Inactive-Male  Inactive-Overall  Obese-Female  \
# 0    2011-AL             65.7           70.6              68.0          32.9
# 1    2011-AK             75.8           79.8              77.9          27.6
# 2    2011-AZ             75.9           76.3              76.1          26.7
# 3    2011-AR             67.2           72.9              70.0          32.4
# 4    2011-CA             80.1           81.8              80.9          25.1
#
#    Obese-Male  Obese-Overall  Diabetic-Female  Diabetic-Male  \
# 0        32.9           32.9             11.4           10.4
# 1        28.6           28.1              8.6            8.1
# 2        24.9           25.7              8.1           10.0
# 3        31.0           31.6              9.7           11.2
# 4        23.9           24.6              7.9            9.2
#
#    Diabetic-Overall  ...  Major CV Disease-Overall  current_overall  \
# 0              10.8  ...                       9.9             24.3
# 1               8.4  ...                       6.5             22.9
# 2               9.0  ...                       7.8             19.3
# 3              10.4  ...                       9.8             27.0
# 4               8.4  ...                       6.6             13.7
#
#    current_female  current_male  Never_overall  Never_female  Never_male  \
# 0            21.0          28.0           50.6          58.8        41.5
# 1            23.0          22.9           49.1          52.2        46.2
# 2            17.5          21.0           55.9          61.3        50.3
# 3            25.2          28.9           47.9          53.0        42.6
# 4            10.0          17.3           62.5          70.1        54.8
#
#    Former_overall  Former_female  Former_male
# 0            25.1           20.1         30.5
# 1            27.9           24.9         30.8
# 2            24.9           21.1         28.7
# 3            25.1           21.8         28.6
# 4            23.9           19.9         27.9
#
# [5 rows x 31 columns]

# %%
# define X (inputs) and y (target/output)
X = merged_df.drop(columns = ["Year-State","Major CV Disease-Overall"], axis=1)
y = merged_df[['Major CV Disease-Overall']]

# %%
print(X.shape, y.shape)
# Out:
# (407, 29) (407, 1)

# %%
X = np.array(X)
y = np.array(y)

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (305, 29) (102, 29) (305, 1) (102, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
# Create scaler instance
min_max_scaler = MinMaxScaler()

X_scaler = min_max_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=29))

# %%
# Add our hidden layer layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu"))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 150
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 186 (744.00 Byte)
# Trainable params: 186 (744.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# Fit the model to the training data
fit_model = nn_model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                    epochs=100,
                    verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 15ms/step - loss: 57.0357 - mae: 7.4013 - val_loss: 47.8992 - val_mae: 6.7766
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 39.4837 - mae: 6.0867 - val_loss: 28.6303 - val_mae: 5.1573
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.6869 - mae: 4.3506 - val_loss: 13.4313 - val_mae: 3.3719
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.3841 - mae: 2.5936 - val_loss: 5.0044 - val_mae: 1.7566
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 3.7653 - mae: 1.4098 - val_loss: 2.3080 - val_mae: 1.1274
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.4691 - mae: 1.1918 - val_loss: 2.0506 - val_mae: 1.1302
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3570 - mae: 1.2203 - val_loss: 2.0154 - val_mae: 1.1078
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.3208 - mae: 1.2031 - val_loss: 1.9586 - val_mae: 1.0927
# Epoch 9/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2905 - mae: 1.2092 - val_loss: 1.8934 - val_mae: 1.0745
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2282 - mae: 1.1796 - val_loss: 1.9129 - val_mae: 1.0442
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1096 - mae: 1.1326 - val_loss: 1.8881 - val_mae: 1.1112
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1007 - mae: 1.1549 - val_loss: 1.7044 - val_mae: 1.0350
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0020 - mae: 1.1242 - val_loss: 1.6455 - val_mae: 1.0153
# Epoch 14/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9073 - mae: 1.0928 - val_loss: 1.6812 - val_mae: 1.0437
# Epoch 15/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8434 - mae: 1.0918 - val_loss: 1.7199 - val_mae: 0.9706
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8114 - mae: 1.0631 - val_loss: 1.5580 - val_mae: 0.9379
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7230 - mae: 1.0339 - val_loss: 1.5003 - val_mae: 0.9856
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6919 - mae: 1.0485 - val_loss: 1.3689 - val_mae: 0.9035
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5699 - mae: 0.9915 - val_loss: 1.3433 - val_mae: 0.8835
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5547 - mae: 0.9862 - val_loss: 1.2723 - val_mae: 0.8652
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4690 - mae: 0.9699 - val_loss: 1.2348 - val_mae: 0.8450
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4001 - mae: 0.9383 - val_loss: 1.2043 - val_mae: 0.8270
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.3651 - mae: 0.9250 - val_loss: 1.1653 - val_mae: 0.8098
# Epoch 24/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2771 - mae: 0.8871 - val_loss: 1.0941 - val_mae: 0.7894
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2438 - mae: 0.8766 - val_loss: 1.0961 - val_mae: 0.7793
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1913 - mae: 0.8594 - val_loss: 0.9338 - val_mae: 0.7527
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0956 - mae: 0.8295 - val_loss: 0.8750 - val_mae: 0.7377
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0679 - mae: 0.8252 - val_loss: 0.8559 - val_mae: 0.7340
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0256 - mae: 0.8110 - val_loss: 0.8113 - val_mae: 0.6868
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9653 - mae: 0.7690 - val_loss: 0.8341 - val_mae: 0.6823
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9075 - mae: 0.7498 - val_loss: 0.6970 - val_mae: 0.6552
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8757 - mae: 0.7423 - val_loss: 0.6616 - val_mae: 0.6332
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8083 - mae: 0.7131 - val_loss: 0.6383 - val_mae: 0.6129
# Epoch 34/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7587 - mae: 0.6813 - val_loss: 0.6634 - val_mae: 0.6115
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7144 - mae: 0.6573 - val_loss: 0.5516 - val_mae: 0.5702
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6852 - mae: 0.6500 - val_loss: 0.5061 - val_mae: 0.5493
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6203 - mae: 0.6212 - val_loss: 0.4634 - val_mae: 0.5297
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5499 - mae: 0.5812 - val_loss: 0.5017 - val_mae: 0.5392
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5463 - mae: 0.5790 - val_loss: 0.4141 - val_mae: 0.4933
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4866 - mae: 0.5503 - val_loss: 0.3855 - val_mae: 0.4769
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4622 - mae: 0.5301 - val_loss: 0.3500 - val_mae: 0.4553
# Epoch 42/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4210 - mae: 0.5025 - val_loss: 0.3111 - val_mae: 0.4230
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4144 - mae: 0.5026 - val_loss: 0.2916 - val_mae: 0.4107
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3807 - mae: 0.4771 - val_loss: 0.2990 - val_mae: 0.4173
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3768 - mae: 0.4835 - val_loss: 0.2652 - val_mae: 0.3968
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3315 - mae: 0.4409 - val_loss: 0.2759 - val_mae: 0.4004
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3402 - mae: 0.4485 - val_loss: 0.2512 - val_mae: 0.3792
# Epoch 48/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3114 - mae: 0.4326 - val_loss: 0.2301 - val_mae: 0.3706
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3143 - mae: 0.4386 - val_loss: 0.2198 - val_mae: 0.3592
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2868 - mae: 0.4160 - val_loss: 0.2261 - val_mae: 0.3673
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2850 - mae: 0.4199 - val_loss: 0.2268 - val_mae: 0.3735
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2912 - mae: 0.4203 - val_loss: 0.2352 - val_mae: 0.3847
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2768 - mae: 0.4098 - val_loss: 0.2126 - val_mae: 0.3594
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2641 - mae: 0.3997 - val_loss: 0.1971 - val_mae: 0.3477
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2731 - mae: 0.4167 - val_loss: 0.2289 - val_mae: 0.3805
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2664 - mae: 0.4106 - val_loss: 0.1930 - val_mae: 0.3438
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2496 - mae: 0.3959 - val_loss: 0.1898 - val_mae: 0.3436
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2504 - mae: 0.4002 - val_loss: 0.2158 - val_mae: 0.3700
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2534 - mae: 0.4010 - val_loss: 0.2935 - val_mae: 0.4424
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2554 - mae: 0.3946 - val_loss: 0.2585 - val_mae: 0.4110
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2310 - mae: 0.3784 - val_loss: 0.2130 - val_mae: 0.3652
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2767 - mae: 0.4233 - val_loss: 0.1843 - val_mae: 0.3409
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2494 - mae: 0.3933 - val_loss: 0.1894 - val_mae: 0.3467
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2408 - mae: 0.3802 - val_loss: 0.2155 - val_mae: 0.3685
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2277 - mae: 0.3716 - val_loss: 0.1819 - val_mae: 0.3359
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2178 - mae: 0.3634 - val_loss: 0.2024 - val_mae: 0.3550
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2522 - mae: 0.4003 - val_loss: 0.1899 - val_mae: 0.3488
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2495 - mae: 0.3889 - val_loss: 0.2393 - val_mae: 0.3973
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2500 - mae: 0.4012 - val_loss: 0.1714 - val_mae: 0.3287
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2154 - mae: 0.3644 - val_loss: 0.1669 - val_mae: 0.3252
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2130 - mae: 0.3631 - val_loss: 0.3098 - val_mae: 0.4640
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2174 - mae: 0.3780 - val_loss: 0.2651 - val_mae: 0.4249
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2091 - mae: 0.3567 - val_loss: 0.2696 - val_mae: 0.4280
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2364 - mae: 0.3856 - val_loss: 0.1768 - val_mae: 0.3304
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2101 - mae: 0.3592 - val_loss: 0.1877 - val_mae: 0.3405
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2120 - mae: 0.3614 - val_loss: 0.1778 - val_mae: 0.3382
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2131 - mae: 0.3642 - val_loss: 0.1599 - val_mae: 0.3183
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2197 - mae: 0.3692 - val_loss: 0.1964 - val_mae: 0.3585
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1990 - mae: 0.3488 - val_loss: 0.1747 - val_mae: 0.3281
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1960 - mae: 0.3486 - val_loss: 0.2626 - val_mae: 0.4234
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2081 - mae: 0.3589 - val_loss: 0.1644 - val_mae: 0.3255
# Epoch 82/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2074 - mae: 0.3544 - val_loss: 0.1492 - val_mae: 0.3091
# Epoch 83/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2063 - mae: 0.3539 - val_loss: 0.1480 - val_mae: 0.3074
# Epoch 84/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1989 - mae: 0.3490 - val_loss: 0.1586 - val_mae: 0.3197
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1824 - mae: 0.3417 - val_loss: 0.1450 - val_mae: 0.3047
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2051 - mae: 0.3520 - val_loss: 0.1854 - val_mae: 0.3489
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1984 - mae: 0.3552 - val_loss: 0.2056 - val_mae: 0.3679
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2010 - mae: 0.3528 - val_loss: 0.1429 - val_mae: 0.3023
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1982 - mae: 0.3420 - val_loss: 0.1403 - val_mae: 0.2999
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1922 - mae: 0.3449 - val_loss: 0.1580 - val_mae: 0.3194
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1930 - mae: 0.3509 - val_loss: 0.2090 - val_mae: 0.3734
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1891 - mae: 0.3433 - val_loss: 0.1393 - val_mae: 0.2990
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2000 - mae: 0.3566 - val_loss: 0.1366 - val_mae: 0.2958
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1793 - mae: 0.3352 - val_loss: 0.1599 - val_mae: 0.3138
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1802 - mae: 0.3288 - val_loss: 0.1333 - val_mae: 0.2926
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1709 - mae: 0.3259 - val_loss: 0.1473 - val_mae: 0.3083
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1827 - mae: 0.3366 - val_loss: 0.1487 - val_mae: 0.3105
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1779 - mae: 0.3292 - val_loss: 0.1807 - val_mae: 0.3469
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1720 - mae: 0.3295 - val_loss: 0.1978 - val_mae: 0.3631
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1776 - mae: 0.3373 - val_loss: 0.1583 - val_mae: 0.3139

# %%
history_dict = fit_model.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# scatterplot of actual vs. pred
# specify the dimensions 
fig, axes = plt.subplots(1,2) # 1 row, 2 columns

# this makes the individual subplots
# Training Results
axes[0].scatter(x=y_train, y=nn_model.predict(X_train)) #first row, first entry (left top)
axes[0].set_xlabel("Actual", fontsize=10)
axes[0].set_ylabel("Predicted",  fontsize=10)
axes[0].set_title("Training")
# add 45 deg line
x = np.linspace(*axes[0].get_xlim())
axes[0].plot(x, x, color='red')
# Validation Results
axes[1].scatter(x=y_test, y=nn_model.predict(X_test)) # first row, second entry (right top)
axes[1].set_xlabel("Actual", fontsize=10)
axes[1].set_ylabel("Predicted",  fontsize=10)
axes[1].set_title("Validation")
# add 45 deg line
x = np.linspace(*axes[1].get_xlim())
axes[1].plot(x, x, color='red')

# tight layout
fig.tight_layout()

# show the plot
plt.show()
# Out:
# 10/10 [==============================] - 0s 776us/step
# 4/4 [==============================] - 0s 997us/step

# %%
# metrics
pred = nn_model.predict(X_test)
pred

trainpreds = nn_model.predict(X_train)

from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_train, trainpreds)) # train
print(mean_absolute_error(y_test, pred)) # test
# Out:
# 4/4 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 776us/step
# 0.3268995144328133
# 0.3138736248016358

# %%
# if needed can create second model to try and optimize
